# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned.csv")

# %%
df.head()
# Out:
#        Price Transmisson        Colour  Make Year  Mileage  Engine (CC)  \
# 0   750000.0    Auto-2WD    Light blue     2005.0     11.0       1399.0
# 1   700000.0  Manual-2WD         White     2013.0     15.0       2956.0
# 2   600000.0  Manual-4WD         white     2017.0     15.0      50000.0
# 3      375.0    Auto-2WD         white     2019.0     17.0       1200.0
# 4  1400000.0  Manual-2WD  Artic Silver     2014.0     12.0       2956.0
#
#      Fuel  Kilometer Run     Brand
# 0  Petrol        87412.0   Hyundai
# 1  Diesel        60000.0      Tata
# 2  Diesel        50000.0  Mahindra
# 3  Petrol         2400.0   Hyundai
# 4  Diesel        50000.0      Tata

# %% [markdown]
# # Applying ML model

# %%
pip install jupyterthemes
# Out:
# ...
#
#   Obtaining dependency information for jupyterthemes from https://files.pythonhosted.org/packages/8a/08/9dee6dfd7f2aad6c30282d55c8f495b4dc1e4747b4e2bdbeb80572ddf312/jupyterthemes-0.20.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for lesscpy>=0.11.2 from https://files.pythonhosted.org/packages/2a/da/4a20ba69c9c71ce3d522da5a3c617254d1d1430b71f52b7d46dbf2c06b96/lesscpy-0.15.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB 660.6 kB/s eta 0:00:11
#    ---------------------------------------- 0.1/7.0 MB 657.6 kB/s eta 0:00:11
#     --------------------------------------- 0.1/7.0 MB 819.2 kB/s eta 0:00:09
#    - -------------------------------------- 0.2/7.0 MB 958.4 kB/s eta 0:00:08
#    - -------------------------------------- 0.2/7.0 MB 1.1 MB/s eta 0:00:07
# ...

# %%
import jupyterthemes as jt
jt -t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import jupyterthemes as jt
# ----> 2 jt -t
#
# NameError: name 't' is not defined

# %%
jt -t <theme-name>
