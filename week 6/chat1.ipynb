# %%
from langchain.document_loaders import DirectoryLoader

directory = '\\Users\\hp\\Desktop\\FDV\\week 6\\pdf'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# yolox_l0.05.onnx: 100%|██████████| 217M/217M [02:44<00:00, 1.31MB/s]
# Error loading file \Users\hp\Desktop\FDV\week 6\pdf\History_Ancient_Medieval_Nepal.pdf
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\envs\asd\lib\site-packages\pdf2image\pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File ~\anaconda3\envs\asd\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File ~\anaconda3\envs\asd\lib\subprocess.py:1456, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1455 try:
# -> 1456     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1457                              # no special security
#    1458                              None, None,
#    1459                              int(not close_fds),
#    1460                              creationflags,
#    1461                              env,
#    1462                              cwd,
#    1463                              startupinfo)
#    1464 finally:
#    1465     # Child is launched. Close the parent's copy of those pipe
#    1466     # handles that only the child should have open.  You need
#    (...)
#    1469     # pipe will not close when the child process exits and the
#    1470     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# Cell In[5], line 10
#       7   documents = loader.load()
#       8   return documents
# ---> 10 documents = load_docs(directory)
#      11 len(documents)
#
# Cell In[5], line 7, in load_docs(directory)
#       5 def load_docs(directory):
#       6   loader = DirectoryLoader(directory)
# ----> 7   documents = loader.load()
#       8   return documents
#
# File ~\anaconda3\envs\asd\lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File ~\anaconda3\envs\asd\lib\site-packages\langchain_community\document_loaders\directory.py:182, in DirectoryLoader.lazy_load(self)
#     180 else:
#     181     for i in items:
# --> 182         yield from self._lazy_load_file(i, p, pbar)
#     184 if pbar:
#     185     pbar.close()
#
# File ~\anaconda3\envs\asd\lib\site-packages\langchain_community\document_loaders\directory.py:220, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     218     else:
#     219         logger.error(f"Error loading file {str(item)}")
# --> 220         raise e
#     221 finally:
#     222     if pbar:
#
# File ~\anaconda3\envs\asd\lib\site-packages\langchain_community\document_loaders\directory.py:210, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     208 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     209 try:
# --> 210     for subdoc in loader.lazy_load():
#     211         yield subdoc
#     212 except NotImplementedError:
#
# File ~\anaconda3\envs\asd\lib\site-packages\langchain_community\document_loaders\unstructured.py:88, in UnstructuredBaseLoader.lazy_load(self)
#      86 def lazy_load(self) -> Iterator[Document]:
#      87     """Load file."""
# ---> 88     elements = self._get_elements()
#      89     self._post_process_elements(elements)
#      90     if self.mode == "elements":
#
# File ~\anaconda3\envs\asd\lib\site-packages\langchain_community\document_loaders\unstructured.py:180, in UnstructuredFileLoader._get_elements(self)
#     178 if isinstance(self.file_path, Path):
#     179     self.file_path = str(self.file_path)
# --> 180 return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\partition\auto.py:426, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, detect_language_per_element, pdf_infer_table_structure, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, xml_keep_tags, data_source_metadata, metadata_filename, request_timeout, hi_res_model_name, model_name, date_from_file_object, starting_page_number, **kwargs)
#     424 elif filetype == FileType.PDF:
#     425     _partition_pdf = _get_partition_with_extras("pdf")
# --> 426     elements = _partition_pdf(
#     427         filename=filename,
#     428         file=file,
#     429         url=None,
#     430         include_page_breaks=include_page_breaks,
#     431         infer_table_structure=infer_table_structure,
#     432         strategy=strategy,
#     433         languages=languages,
#     434         hi_res_model_name=hi_res_model_name or model_name,
#     435         extract_images_in_pdf=extract_images_in_pdf,
#     436         extract_image_block_types=extract_image_block_types,
#     437         extract_image_block_output_dir=extract_image_block_output_dir,
#     438         extract_image_block_to_payload=extract_image_block_to_payload,
#     439         starting_page_number=starting_page_number,
#     440         **kwargs,
#     441     )
#     442 elif filetype in IMAGE_FILETYPES:
#     443     _partition_image = _get_partition_with_extras("image")
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\documents\elements.py:570, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     568 @functools.wraps(func)
#     569 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 570     elements = func(*args, **kwargs)
#     571     sig = inspect.signature(func)
#     572     params: dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\file_utils\filetype.py:622, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     620 @functools.wraps(func)
#     621 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 622     elements = func(*args, **kwargs)
#     623     sig = inspect.signature(func)
#     624     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\file_utils\filetype.py:582, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     580 @functools.wraps(func)
#     581 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 582     elements = func(*args, **kwargs)
#     583     sig = inspect.signature(func)
#     584     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\chunking\dispatch.py:83, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      80     return call_args
#      82 # -- call the partitioning function to get the elements --
# ---> 83 elements = func(*args, **kwargs)
#      85 # -- look for a chunking-strategy argument --
#      86 call_args = get_call_args_applying_defaults()
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\partition\pdf.py:201, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, links, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, **kwargs)
#     197 exactly_one(filename=filename, file=file)
#     199 languages = check_language_args(languages or [], ocr_languages) or ["eng"]
# --> 201 return partition_pdf_or_image(
#     202     filename=filename,
#     203     file=file,
#     204     include_page_breaks=include_page_breaks,
#     205     strategy=strategy,
#     206     infer_table_structure=infer_table_structure,
#     207     languages=languages,
#     208     metadata_last_modified=metadata_last_modified,
#     209     hi_res_model_name=hi_res_model_name,
#     210     extract_images_in_pdf=extract_images_in_pdf,
#     211     extract_image_block_types=extract_image_block_types,
#     212     extract_image_block_output_dir=extract_image_block_output_dir,
#     213     extract_image_block_to_payload=extract_image_block_to_payload,
#     214     date_from_file_object=date_from_file_object,
#     215     starting_page_number=starting_page_number,
#     216     **kwargs,
#     217 )
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\partition\pdf.py:292, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, metadata_last_modified, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, date_from_file_object, starting_page_number, **kwargs)
#     290     with warnings.catch_warnings():
#     291         warnings.simplefilter("ignore")
# --> 292         elements = _partition_pdf_or_image_local(
#     293             filename=filename,
#     294             file=spooled_to_bytes_io_if_needed(file),
#     295             is_image=is_image,
#     296             infer_table_structure=infer_table_structure,
#     297             include_page_breaks=include_page_breaks,
#     298             languages=languages,
#     299             metadata_last_modified=metadata_last_modified or last_modification_date,
#     300             hi_res_model_name=hi_res_model_name,
#     301             pdf_text_extractable=pdf_text_extractable,
#     302             extract_images_in_pdf=extract_images_in_pdf,
#     303             extract_image_block_types=extract_image_block_types,
#     304             extract_image_block_output_dir=extract_image_block_output_dir,
#     305             extract_image_block_to_payload=extract_image_block_to_payload,
#     306             starting_page_number=starting_page_number,
#     307             **kwargs,
#     308         )
#     309         out_elements = _process_uncategorized_text_elements(elements)
#     311 elif strategy == PartitionStrategy.FAST:
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\utils.py:230, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     221 if len(missing_deps) > 0:
#     222     raise ImportError(
#     223         f"Following dependencies are missing: {', '.join(missing_deps)}. "
#     224         + (
#    (...)
#     228         ),
#     229     )
# --> 230 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured\partition\pdf.py:422, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_mode, model_name, hi_res_model_name, pdf_image_dpi, metadata_last_modified, pdf_text_extractable, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, analysis, analyzed_image_output_dir_path, starting_page_number, **kwargs)
#     416     logger.warning(
#     417         "The Chipper model performs better when images are rendered with DPI >= 300 "
#     418         f"(currently {pdf_image_dpi}).",
#     419     )
#     421 if file is None:
# --> 422     inferred_document_layout = process_file_with_model(
#     423         filename,
#     424         is_image=is_image,
#     425         model_name=hi_res_model_name,
#     426         pdf_image_dpi=pdf_image_dpi,
#     427     )
#     429     if hi_res_model_name.startswith("chipper"):
#     430         # NOTE(alan): We shouldn't do OCR with chipper
#     431         # NOTE(antonio): We shouldn't do PDFMiner with chipper
#     432         final_document_layout = inferred_document_layout
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured_inference\inference\layout.py:396, in process_file_with_model(filename, model_name, is_image, fixed_layouts, pdf_image_dpi, **kwargs)
#     386 else:
#     387     raise ValueError(f"Unsupported model type: {type(model)}")
#     388 layout = (
#     389     DocumentLayout.from_image_file(
#     390         filename,
#     391         detection_model=detection_model,
#     392         element_extraction_model=element_extraction_model,
#     393         **kwargs,
#     394     )
#     395     if is_image
# --> 396     else DocumentLayout.from_file(
#     397         filename,
#     398         detection_model=detection_model,
#     399         element_extraction_model=element_extraction_model,
#     400         fixed_layouts=fixed_layouts,
#     401         pdf_image_dpi=pdf_image_dpi,
#     402         **kwargs,
#     403     )
#     404 )
#     405 return layout
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured_inference\inference\layout.py:64, in DocumentLayout.from_file(cls, filename, fixed_layouts, pdf_image_dpi, **kwargs)
#      61 logger.info(f"Reading PDF for file: {filename} ...")
#      63 with tempfile.TemporaryDirectory() as temp_dir:
# ---> 64     _image_paths = convert_pdf_to_image(
#      65         filename,
#      66         pdf_image_dpi,
#      67         output_folder=temp_dir,
#      68         path_only=True,
#      69     )
#      70     image_paths = cast(List[str], _image_paths)
#      71     number_of_pages = len(image_paths)
#
# File ~\anaconda3\envs\asd\lib\site-packages\unstructured_inference\inference\layout.py:433, in convert_pdf_to_image(filename, dpi, output_folder, path_only)
#     430     raise ValueError("output_folder must be specified if path_only is true")
#     432 if output_folder is not None:
# --> 433     images = pdf2image.convert_from_path(
#     434         filename,
#     435         dpi=dpi,
#     436         output_folder=output_folder,
#     437         paths_only=path_only,
#     438     )
#     439 else:
#     440     images = pdf2image.convert_from_path(
#     441         filename,
#     442         dpi=dpi,
#     443         paths_only=path_only,
#     444     )
#
# File ~\anaconda3\envs\asd\lib\site-packages\pdf2image\pdf2image.py:127, in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     124 if isinstance(poppler_path, PurePath):
#     125     poppler_path = poppler_path.as_posix()
# --> 127 page_count = pdfinfo_from_path(
#     128     pdf_path, userpw, ownerpw, poppler_path=poppler_path
#     129 )["Pages"]
#     131 # We start by getting the output format, the buffer processing function and if we need pdftocairo
#     132 parsed_fmt, final_extension, parse_buffer_func, use_pdfcairo_format = _parse_format(
#     133     fmt, grayscale
#     134 )
#
# File ~\anaconda3\envs\asd\lib\site-packages\pdf2image\pdf2image.py:607, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     604     return d
#     606 except OSError:
# --> 607     raise PDFInfoNotInstalledError(
#     608         "Unable to get page count. Is poppler installed and in PATH?"
#     609     )
#     610 except ValueError:
#     611     raise PDFPageCountError(
#     612         f"Unable to get page count.\n{err.decode('utf8', 'ignore')}"
#     613     )
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=500,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))

# %%
from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
#Install Poppler and pdf2image
# !apt-get install poppler-utils
# !pip install pdf2image

# Install Tesseract
# !apt-get install tesseract-ocr

# Install pytesseract
# !pip install pytesseract
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: pdf2image in c:\users\hp\anaconda3\envs\asd\lib\site-packages (1.17.0)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\envs\asd\lib\site-packages (from pdf2image) (10.3.0)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: pytesseract in c:\users\hp\anaconda3\envs\asd\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\envs\asd\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\hp\anaconda3\envs\asd\lib\site-packages (from pytesseract) (10.3.0)
